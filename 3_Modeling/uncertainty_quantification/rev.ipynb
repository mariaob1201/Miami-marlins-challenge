# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('outputs/predictions_next_season_by_player.csv')

validate = pd.read_csv('../1_Data/exit_velo_validate_data.csv')
print(validate.columns, '---', df.columns)
# Out:
# Index(['season', 'batter_id', 'age'], dtype='object') --- Index(['batter_id', 'latent_lo', 'latent_med', 'latent_hi', 'pred_obs_lo',
#        'pred_obs_med', 'pred_obs_hi', 'assumed_n_future', 'latent_width',
#        'pred_width', 'uncertainty_ratio'],
#       dtype='object')

# %%
merge_w_validate = validate.merge(df, on='batter_id', how='left')


print(len(merge_w_validate), len(validate))
# Out:
# 647 647

# %%
len(merge_w_validate[merge_w_validate['pred_obs_med'].isna()])
# Out:
# 204

# %%
# No prediction
merge_w_validate[merge_w_validate['pred_obs_med'].isna()]
# Out:
#      season  batter_id   age  latent_lo  latent_med  latent_hi  pred_obs_lo  \
# 0      2024          2  25.4        NaN         NaN        NaN          NaN
# 2      2024          9  22.3        NaN         NaN        NaN          NaN
# 3      2024         11  26.8        NaN         NaN        NaN          NaN
# 9      2024         44  26.9        NaN         NaN        NaN          NaN
# 12     2024         52  25.3        NaN         NaN        NaN          NaN
# ..      ...        ...   ...        ...         ...        ...          ...
# 628    2024       4016  24.1        NaN         NaN        NaN          NaN
# 630    2024       4030  23.4        NaN         NaN        NaN          NaN
# 632    2024       4050  27.2        NaN         NaN        NaN          NaN
# 638    2024       4080  23.6        NaN         NaN        NaN          NaN
# 642    2024       4088  25.9        NaN         NaN        NaN          NaN
#
# ...
